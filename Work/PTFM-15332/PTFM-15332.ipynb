# %%
# ================================================
# Section 1: Imports and Configuration
# ================================================
import requests
import pandas as pd
from datetime import datetime
import os
import xml.etree.ElementTree as ET
import time
from datetime import timedelta
import urllib.parse

# API Keys (Replace with your actual values)
PORTCALL_API_KEYS = {
    "US": "d3246633f0e6efa7115aa9e3699b374e80cd70b5",
    "SEA": "8664b14b5a58bd5df0bcb7a878aa0c1125fdc7bf",
    "ES": "your_spain_api_key_here",
    "UK": "your_uk_api_key_here",
    "CN": "706596ba566e8c464edbd3cd8c80ef3832bec9d7",
    # Add more country codes and keys as needed
}

# Power Tools API Keys and Fleet ID
CLEARFLEET_API_KEY = "db93f3fc9b4dbb584ac62c015921f20d0ba118e0"
SETFLEET_API_KEY = "9a15e55d03b529cf8eacb415c27fc254ad4e0c22"
FLEET_ID = 3174244

# New API key for fleet portcalls (Step 4)
FLEET_PORTCALL_API_KEY = "c2fa0eb6e9208dfb96d55228fd88a3ce34e37844"

# Set API endpoints and keys
GRAPHQL_URL = "https://api.kpler.marinetraffic.com/v2/vessels/graphql"
GRAPHQL_API_KEY = "RTZCQWF2ZHJpWWVheXJZTmZIenFNRXFzZTQzdDNaUEQ6MU1vZ0dqWUQtZHFMMXNTMnNER21CZzNzSjcyUUdzQ0hfSHBFWlFRTk9pT2NwVWpzeF9TclZ0QzNvU0NwMlJpQg=="

MARKET_OPTIONS = [
    "CONTAINER SHIPS", "DRY BREAKBULK", "DRY BULK", "LNG CARRIERS",
    "LPG CARRIERS", "WET BULK", "PASSENGER SHIPS", "OFFSHORE/RIGS",
    "RO/RO", "SUPPORTING VESSELS", "PLEASURE CRAFT", "FISHING", "OTHER MARKETS"
]

# %%
# ================================================
# Section 2: Helper Input Functions
# ================================================
def safe_input(prompt, validate_func=None, allowed_values=None):
    while True:
        user_input = input(prompt).strip()
        if user_input.upper() == 'ESC':
            raise KeyboardInterrupt("User pressed ESC - exiting.")
        if not user_input:
            print("Input cannot be empty. Please try again or type ESC to exit.")
            continue
        if allowed_values and user_input.upper() not in allowed_values:
            print(f"Invalid option. Allowed: {', '.join(allowed_values)}")
            continue
        if validate_func:
            try:
                return validate_func(user_input)
            except Exception as e:
                print(f"Invalid input: {e}")
                continue
        else:
            return user_input

def get_user_portcall_input():
    allowed_regions = set(PORTCALL_API_KEYS.keys())
    region = safe_input(f"Select region/country code {sorted(allowed_regions)}: ", allowed_values=allowed_regions).upper()
    
    def validate_date(d): return datetime.strptime(d, "%Y-%m-%d")
    fromdate = safe_input("Enter fromdate (YYYY-MM-DD): ", validate_func=validate_date)
    todate = safe_input("Enter todate (YYYY-MM-DD): ", validate_func=validate_date)
    
    from_date = fromdate.strftime('%Y-%m-%d 00:00:00')
    to_date = todate.strftime('%Y-%m-%d 23:59:00')
    
    print("\nAvailable Market Types:")
    for i, m in enumerate(MARKET_OPTIONS, 1): print(f"{i}. {m}")
    
    def validate_markets(m):
        indices = [int(i.strip()) - 1 for i in m.split(",")]
        return [MARKET_OPTIONS[i] for i in indices]
    
    market_list = safe_input("Select market(s) by number: ", validate_func=validate_markets)
    movetype = 0 # or allow user input as before
    
    return region, from_date, to_date, market_list, movetype

def split_date_range(start_date, end_date, max_days=190):
    """
    Splits a date range into chunks of max_days.
    Returns a list of (chunk_start, chunk_end) tuples.
    """
    chunks = []
    current_start = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)
    while current_start < end_date:
        current_end = min(current_start + timedelta(days=max_days-1), end_date)
        chunks.append((current_start.strftime('%Y-%m-%d %H:%M:%S'), current_end.strftime('%Y-%m-%d %H:%M:%S')))
        current_start = current_end + timedelta(seconds=1)
    return chunks

# %%
# ================================================
# Section 3: PortCall API Functions
# ================================================
def build_portcall_url(api_key, fromdate, todate, msgtype='extended', market=None, movetype=0):
    base_url = f"https://services.marinetraffic.com/api/portcalls/{api_key}"
    params = {
        "v": 6,
        "fromdate": fromdate,
        "todate": todate,
        "msgtype": msgtype,
        "protocol": "jsono",
        "movetype": movetype
    }
    if market:
        params["market"] = market
    query = "&".join(f"{k}={urllib.parse.quote(str(v))}" for k, v in params.items())
    return f"{base_url}?{query}"

def fetch_portcall_data_single(region, from_date, to_date, market_list, movetype):
    api_key = PORTCALL_API_KEYS[region]
    all_data = []
    for market in market_list:
        if movetype in [0, 1]:
            url = build_portcall_url(api_key, from_date, to_date, market=market, movetype=movetype)
            all_data.extend(requests.get(url).json())
        else:
            for mt in [0, 1]:
                url = build_portcall_url(api_key, from_date, to_date, market=market, movetype=mt)
                all_data.extend(requests.get(url).json())
    return all_data

def fetch_portcall_data(region, from_date, to_date, market_list, movetype):
    all_data = []
    date_chunks = split_date_range(from_date, to_date, max_days=190)
    for chunk_start, chunk_end in date_chunks:
        print(f"Fetching port calls from {chunk_start} to {chunk_end}...")
        data = fetch_portcall_data_single(region, chunk_start, chunk_end, market_list, movetype)
        if data:
            all_data.extend(data)
    return all_data

def normalize_portcall_data(data):
    df = pd.json_normalize(data)
    status_map = {0: "NA", 1: "In Ballast", 2: "Partially Laden", 3: "Fully Laden"}
    df = df.rename(columns={
        'IMO': 'IMO', 'SHIPNAME': 'SHIPNAME', 'TIMESTAMP_UTC': 'TIMESTAMP_UTC',
        'MOVE_TYPE': 'MOVE_TYPE', 'PORT_ID': 'PORT_ID', 'PORT_NAME': 'PORT_NAME',
        'SHIP_ID': 'SHIP_ID', 'LOAD_STATUS': 'LOAD_STATUS'
    })
    df['LOAD_STATUS'] = df['LOAD_STATUS'].fillna(0).astype(int).map(status_map).fillna("Unknown")
    # Exclude anchorages and canals
    df = df[~df['PORT_NAME'].str.lower().str.contains('canal|anch', na=False)]
    return df[['IMO', 'SHIPNAME', 'TIMESTAMP_UTC', 'MOVE_TYPE', 'PORT_ID', 'PORT_NAME', 'SHIP_ID', 'LOAD_STATUS']]

def save_df_to_csv(df, prefix="portcalls"):
    filename = f"{prefix}_{datetime.utcnow().strftime('%Y%m%d_%H%M')}.csv"
    df.to_csv(filename, index=False)
    return filename

# %%
# ================================================
# Section 4: ClearFleet API (Clears fleet list)
# ================================================
def build_clearfleet_url(api_key, fleet_id):
    """Build URL for ClearFleet API."""
    return f"https://services.marinetraffic.com/api/clearfleet/{api_key}/fleet_id:{fleet_id}"

def is_clearfleet_successful(xml_text):
    """Parse XML response and return True if fleet cleared successfully."""
    try:
        root = ET.fromstring(xml_text)
        fleet = root.find(".//FLEET")
        if fleet is not None and fleet.attrib.get("DELETE") == "1":
            return True
        return False
    except ET.ParseError:
        return False

def clear_fleet(api_key, fleet_id):
    """Call ClearFleet API to clear a fleet. Returns success status."""
    url = build_clearfleet_url(api_key, fleet_id)
    try:
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()
        if is_clearfleet_successful(resp.text):
            print("✅ Fleet cleared successfully.")
            return True
        else:
            print(f"❌ Unexpected response:\n{resp.text}")
            return False
    except Exception as e:
        print(f"❌ Failed to clear fleet: {e}")
        return False

# %%
# ================================================
# Section 5: SetFleet API – Add IMOs One-by-One
# ================================================
def build_setfleet_batch_url(api_key, fleet_id, imo_list):
    """Build the SetFleet API URL to add multiple vessels by IMO (batch)."""
    imo_str = ",".join(str(imo) for imo in imo_list)
    return f"https://services.marinetraffic.com/api/setfleet/{api_key}/fleet_id:{fleet_id}/imo:{imo_str}/active:1"

def add_vessels_to_fleet(api_key, fleet_id, imo_list, batch_size=300):
    """Add vessels to a MarineTraffic fleet in batches using IMO. Returns success & failed lists."""
    if not imo_list:
        print("No IMOs provided to add to fleet.")
        return [], []

    success_ids = []
    failed_ids = []

    print(f"\n== Step 3: SetFleet (Add Vessels in Batches of {batch_size}) ===")
    print(f"Adding {len(imo_list)} vessels to fleet {fleet_id}...\n")

    for batch_num, start in enumerate(range(0, len(imo_list), batch_size), 1):
        batch = imo_list[start:start+batch_size]
        url = build_setfleet_batch_url(api_key, fleet_id, batch)
        try:
            resp = requests.get(url, timeout=30)
            resp.raise_for_status()
            root = ET.fromstring(resp.text)
            error_nodes = root.findall(".//ERROR")
            error_imos = set()
            for error in error_nodes:
                imo = error.attrib.get("IMO")
                error_imos.add(imo)
                desc = error.attrib.get("DESCRIPTION", "")
                print(f"[Batch {batch_num}] ❌ IMO {imo} failed. Error: {desc}")
                failed_ids.append((imo, desc))
            for imo in batch:
                if imo not in error_imos:
                    print(f"[Batch {batch_num}] ✅ IMO {imo} added.")
                    success_ids.append(imo)
        except Exception as e:
            print(f"[Batch {batch_num}] ❌ Batch error: {e}")
            for imo in batch:
                failed_ids.append((imo, str(e)))
        time.sleep(10)  # Add 10-second buffer between API calls

    # Retry failed IMOs in batches of 50 after waiting 30 seconds
    retry_imos = [imo for imo, _ in failed_ids]
    if retry_imos:
        print(f"\nWaiting 30 seconds before retrying {len(retry_imos)} failed IMOs in batches of 50...")
        time.sleep(30)
        for retry_start in range(0, len(retry_imos), 50):
            retry_batch = retry_imos[retry_start:retry_start+50]
            url = build_setfleet_batch_url(api_key, fleet_id, retry_batch)
            try:
                resp = requests.get(url, timeout=30)
                resp.raise_for_status()
                root = ET.fromstring(resp.text)
                error_nodes = root.findall(".//ERROR")
                error_imos = set()
                for error in error_nodes:
                    imo = error.attrib.get("IMO")
                    error_imos.add(imo)
                    desc = error.attrib.get("DESCRIPTION", "")
                    print(f"[Retry] ❌ IMO {imo} failed again. Error: {desc}")
                    if "not found" in desc.lower():
                        print(f"[Retry] Vessel not found for IMO {imo}.")
                for imo in retry_batch:
                    if imo not in error_imos:
                        print(f"[Retry] ✅ IMO {imo} added on retry.")
                        success_ids.append(imo)
                        failed_ids = [item for item in failed_ids if item[0] != imo]
            except Exception as e:
                print(f"[Retry] ❌ Retry batch error: {e}")
            time.sleep(5)  # Optional: short wait between retry batches

    # Final step: If there are still failed IMOs, run 1 by 1
    final_failed_imos = [imo for imo, _ in failed_ids]
    if final_failed_imos:
        print(f"\nStill {len(final_failed_imos)} IMOs failed. Retrying one by one...")
        for imo in final_failed_imos:
            url = build_setfleet_batch_url(api_key, fleet_id, [imo])
            try:
                resp = requests.get(url, timeout=30)
                resp.raise_for_status()
                root = ET.fromstring(resp.text)
                error_nodes = root.findall(".//ERROR")
                if error_nodes:
                    desc = error_nodes[0].attrib.get("DESCRIPTION", "")
                    print(f"[Final Retry] ❌ IMO {imo} failed. Error: {desc}")
                    if "not found" in desc.lower():
                        print(f"[Final Retry] Vessel not found for IMO {imo}.")
                else:
                    print(f"[Final Retry] ✅ IMO {imo} added.")
                    success_ids.append(imo)
                    failed_ids = [item for item in failed_ids if item[0] != imo]
            except Exception as e:
                print(f"[Final Retry] ❌ IMO {imo} error: {e}")
            time.sleep(2)  # Short wait between single retries

    print(f"\nAdded {len(success_ids)} vessels successfully; {len(failed_ids)} failed.")
    return success_ids, failed_ids

# %%
# ================================================",
# Section 6: Step 4 - Fleet Port Call API (Filtered All Records)",
# ================================================",
from dateutil.relativedelta import relativedelta
from datetime import datetime, timedelta
import time

MAX_DURATION_DAYS = 90

def build_fleet_portcall_url(api_key, fromdate, todate):
    return (
        f"https://services.marinetraffic.com/api/portcalls/{api_key}/v:6/"
        f"fromdate:{fromdate.replace(' ', '%20')}/"
        f"todate:{todate.replace(' ', '%20')}/"
        f"msgtype:extended/protocol:jsono"
    )

def fetch_fleet_portcall_data(api_key, fromdate, todate, max_retries=3, retry_delay=30):
    url = build_fleet_portcall_url(api_key, fromdate, todate)
    for attempt in range(1, max_retries + 1):
        try:
            resp = requests.get(url)
            resp.raise_for_status()
            return resp.json()
        except Exception as e:
            print(f"❌ Fleet portcall API failed (attempt {attempt}/{max_retries}): {e}")
            if attempt < max_retries:
                print(f"Retrying after {retry_delay} seconds...")
                time.sleep(retry_delay)
            else:
                print("Max retries reached. Skipping this chunk.")
                return []

def normalize_fleet_portcalls(data):
    df = pd.json_normalize(data)
    if df.empty:
        return df
    df = df.rename(columns={
        'IMO': 'IMO',
        'SHIPNAME': 'SHIPNAME',
        'TIMESTAMP_UTC': 'TIMESTAMP_UTC',
        'MOVE_TYPE': 'MOVE_TYPE',
        'PORT_ID': 'PORT_ID',
        'PORT_NAME': 'PORT_NAME',
        'PORT_COUNTRY_CODE': 'PORT_COUNTRY_CODE',
        'SHIP_ID': 'SHIP_ID'
    })
    df['TIMESTAMP_UTC'] = pd.to_datetime(df['TIMESTAMP_UTC'])
    # Exclude anchorages and canals
    df = df[~df['PORT_NAME'].str.lower().str.contains('canal|anch', na=False)]
    return df[['IMO', 'SHIPNAME', 'SHIP_ID', 'TIMESTAMP_UTC', 'MOVE_TYPE', 'PORT_ID', 'PORT_NAME', 'PORT_COUNTRY_CODE']]

def save_fleet_portcalls_single(api_key, fromdate_fleet, todate_fleet, region=None):
    all_data = []
    current_start = fromdate_fleet
    while current_start < todate_fleet:
        current_end = min(current_start + timedelta(days=MAX_DURATION_DAYS), todate_fleet)
        print(f"Fetching fleet port calls for region {region} from {current_start} to {current_end}...")
        data = fetch_fleet_portcall_data(
            api_key,
            current_start.strftime('%Y-%m-%d %H:%M:%S'),
            current_end.strftime('%Y-%m-%d %H:%M:%S')
        )
        all_data.extend(data)
        current_start = current_end + timedelta(seconds=1)
    df_fleet = normalize_fleet_portcalls(all_data)
    return df_fleet

def save_fleet_portcalls(api_key, fromdate, todate, region=None):
    region_str = region.lower() if region else "unknown"
    print(f"\n=== Step 4: Fleet Port Call API - All Records for {region_str.upper()} (Excl. region, Departures Only) ===")
    fromdate_fleet = datetime.strptime(fromdate, '%Y-%m-%d %H:%M:%S') - relativedelta(months=2)
    todate_fleet = datetime.strptime(todate, '%Y-%m-%d %H:%M:%S') + relativedelta(months=1)

    all_dfs = []
    date_chunks = split_date_range(fromdate_fleet, todate_fleet, max_days=MAX_DURATION_DAYS)
    for chunk_start, chunk_end in date_chunks:
        df = save_fleet_portcalls_single(api_key, pd.to_datetime(chunk_start), pd.to_datetime(chunk_end), region=region_str)
        if df is not None and not df.empty:
            all_dfs.append(df)
    if all_dfs:
        df_full = pd.concat(all_dfs, ignore_index=True)
        filename = f"{region_str}_fleet_portcalls_filtered_{datetime.utcnow().strftime('%Y%m%d_%H%M')}.csv"
        df_full.to_csv(filename, index=False)
        print(f"✅ Saved fleet port calls to {filename}")
        return filename
    else:
        print(f"No fleet port call data found for region {region_str}.")
        return None

# %%
# ================================================
# Section 7A: Last Departure & Next Arrival (multi-country, robust)
# ================================================

# Define exclusion lists for each region/country code
EXCLUDE_COUNTRIES = {
    "US": ["US"],
    "SEA": ["SG", "MY", "ID", "TH", "VN", "PH", "KH", "MM", "BN", "LA", "TL"],
    "ES": ["ES"],
    "UK": ["GB", "UK"],
    "CN": ["CN"],
    "MX": ["MX"],
    # Add more country codes and their exclusions as needed
}

def enrich_portcalls_with_last_departure(portcalls_df, fleet_df):
    """
    Enriches portcalls_df with last non-region departure info from fleet_df.
    Adds LAST_PORT_ID, LAST_PORT, LAST_PORT_COUNTRY_CODE, LAST_PORT_TIMESTAMP columns.
    """
    portcalls_df = portcalls_df.copy()
    fleet_df = fleet_df.copy()

    portcalls_df["LAST_PORT_ID"] = pd.NA
    portcalls_df["LAST_PORT"] = pd.NA
    portcalls_df["LAST_PORT_COUNTRY_CODE"] = pd.NA
    portcalls_df["LAST_PORT_TIMESTAMP"] = pd.NaT

    fleet_df["TIMESTAMP_UTC"] = pd.to_datetime(fleet_df["TIMESTAMP_UTC"], errors='coerce', utc=True)
    portcalls_df["TIMESTAMP_UTC"] = pd.to_datetime(portcalls_df["TIMESTAMP_UTC"], errors='coerce', utc=True)

    group_col = "SHIP_ID" if "SHIP_ID" in portcalls_df.columns and "SHIP_ID" in fleet_df.columns else "IMO"
    portcalls_df[group_col] = portcalls_df[group_col].astype(str)
    fleet_df[group_col] = fleet_df[group_col].astype(str)
    fleet_grouped = fleet_df.groupby(group_col)

    for idx, row in portcalls_df.iterrows():
        ship_key = str(row[group_col])
        call_time = row["TIMESTAMP_UTC"]

        if ship_key in fleet_grouped.groups:
            vessel_calls = fleet_grouped.get_group(ship_key)
            prior_departures = vessel_calls[
                (vessel_calls["MOVE_TYPE"] == 1) &
                (vessel_calls["TIMESTAMP_UTC"] < call_time)
            ]
            if not prior_departures.empty:
                latest_dep = prior_departures.sort_values("TIMESTAMP_UTC").iloc[-1]
                portcalls_df.loc[idx, "LAST_PORT_ID"] = latest_dep.get("PORT_ID", pd.NA)
                portcalls_df.loc[idx, "LAST_PORT"] = latest_dep.get("PORT_NAME", pd.NA)
                portcalls_df.loc[idx, "LAST_PORT_COUNTRY_CODE"] = latest_dep.get("PORT_COUNTRY_CODE", pd.NA)
                portcalls_df.loc[idx, "LAST_PORT_TIMESTAMP"] = pd.to_datetime(latest_dep["TIMESTAMP_UTC"]).tz_localize(None)

    return portcalls_df

def enrich_portcalls_with_last_departure_region(portcalls_df, fleet_df, region):
    """
    Filters fleet_df to exclude region ports, then enriches portcalls_df with last departure info.
    """
    region = region.strip().upper()
    exclude_countries = EXCLUDE_COUNTRIES.get(region, [])
    fleet_df = fleet_df.copy()
    if exclude_countries and 'PORT_COUNTRY_CODE' in fleet_df.columns:
        fleet_df = fleet_df[
            ~fleet_df['PORT_COUNTRY_CODE'].str.upper().isin(exclude_countries)
        ]
    return enrich_portcalls_with_last_departure(portcalls_df, fleet_df)

def enrich_portcalls_with_next_nonregion_arrival(portcalls_df, fleet_df, region):
    """
    Enriches portcalls_df with next non-region arrival info from fleet_df.
    Adds NEXT_PORT_ID, NEXT_PORT, NEXT_PORT_COUNTRY, NEXT_PORT_TIMESTAMP columns.
    """
    portcalls_df = portcalls_df.copy()
    fleet_df = fleet_df.copy()

    portcalls_df["TIMESTAMP_UTC"] = pd.to_datetime(portcalls_df["TIMESTAMP_UTC"], utc=True)
    fleet_df["TIMESTAMP_UTC"] = pd.to_datetime(fleet_df["TIMESTAMP_UTC"], utc=True)

    region = region.strip().upper()
    exclude_countries = EXCLUDE_COUNTRIES.get(region, [])

    # Filter out arrivals in the region and only arrivals (MOVE_TYPE == 0)
    df_arrivals = fleet_df[
        (~fleet_df["PORT_COUNTRY_CODE"].str.upper().isin(exclude_countries)) &
        (fleet_df["MOVE_TYPE"] == 0)
    ].copy()

    portcalls_df["NEXT_PORT_ID"] = pd.NA
    portcalls_df["NEXT_PORT"] = pd.NA
    portcalls_df["NEXT_PORT_COUNTRY"] = pd.NA
    portcalls_df["NEXT_PORT_TIMESTAMP"] = pd.NaT

    # Use SHIP_ID for grouping if available, else fallback to IMO
    group_col = "SHIP_ID" if "SHIP_ID" in portcalls_df.columns and "SHIP_ID" in df_arrivals.columns else "IMO"
    portcalls_df[group_col] = portcalls_df[group_col].astype(str)
    df_arrivals[group_col] = df_arrivals[group_col].astype(str)
    arrivals_grouped = df_arrivals.groupby(group_col)

    for idx, row in portcalls_df.iterrows():
        ship_key = str(row[group_col])
        call_time = row["TIMESTAMP_UTC"]

        if ship_key in arrivals_grouped.groups:
            vessel_arrivals = arrivals_grouped.get_group(ship_key)
            future_calls = vessel_arrivals[vessel_arrivals["TIMESTAMP_UTC"] > call_time]
            if not future_calls.empty:
                next_arrival = future_calls.sort_values("TIMESTAMP_UTC").iloc[0]
                portcalls_df.loc[idx, "NEXT_PORT_ID"] = next_arrival.get("PORT_ID", pd.NA)
                portcalls_df.loc[idx, "NEXT_PORT"] = next_arrival.get("PORT_NAME", pd.NA)
                portcalls_df.loc[idx, "NEXT_PORT_COUNTRY"] = next_arrival.get("PORT_COUNTRY_CODE", pd.NA)
                portcalls_df.loc[idx, "NEXT_PORT_TIMESTAMP"] = pd.to_datetime(next_arrival["TIMESTAMP_UTC"]).tz_localize(None)

    return portcalls_df

def enrich_portcalls_with_last_and_next(portcalls_df, fleet_df, region):
    """
    Runs both last departure and next arrival enrichment for the selected region.
    """
    df = enrich_portcalls_with_last_departure_region(portcalls_df, fleet_df, region)
    df = enrich_portcalls_with_next_nonregion_arrival(df, fleet_df, region)
    return df

# %%
# ================================================
# Section 8: Fetch TEU/CAPACITY from MT GraphQL API
# ================================================
# ...existing code...
def fetch_teu_by_imo_list(imo_list, batch_size=500):
    """
    Fetch teuCapacity and ceuCapacity for a list of IMOs using the Kpler GraphQL API.
    Returns a DataFrame with columns: IMO, TEU/CAPACITY, CEU/CAPACITY
    """
    results = []
    for i in range(0, len(imo_list), batch_size):
        batch = imo_list[i:i+batch_size]
        query = f"""
        query Vessels {{
            vessels(
                first: {len(batch)}
                where: {{
                    filters: [
                        {{
                            field: "identifier.imo"
                            op: IN
                            values: [{','.join(f'"{imo}"' for imo in batch)}]
                        }}
                    ]
                    operator: OR
                }}
            ) {{
                nodes {{
                    identifier {{ imo }}
                    particulars {{
                        capacity {{ teuCapacity ceuCapacity }}
                    }}
                }}
            }}
        }}
        """

        headers = {
            "Authorization": f"Basic {GRAPHQL_API_KEY}",
            "Content-Type": "application/json"
        }

        response = requests.post(GRAPHQL_URL, json={"query": query}, headers=headers)
        if response.status_code != 200:
            print(f"Error {response.status_code}: {response.text}")
            continue

        data = response.json()
        vessels = data.get("data", {}).get("vessels", {}).get("nodes", [])
        for vessel in vessels:
            imo = vessel.get("identifier", {}).get("imo")
            teu = None
            ceu = None
            particulars = vessel.get("particulars", {})
            if particulars and particulars.get("capacity"):
                teu = particulars["capacity"].get("teuCapacity")
                ceu = particulars["capacity"].get("ceuCapacity")
            results.append({"IMO": imo, "TEU/CAPACITY": teu, "CEU/CAPACITY": ceu})

    import pandas as pd
    return pd.DataFrame(results)

# %%
# ================================================
# Section 9a: Aggregation of Total Arrivals / Vessel Count to US Ports / TEU/capacity Totals
# ================================================
def aggregate_total_port_arrivals(df_enriched, output_filename=None):
    """
    Aggregates total arrivals, unique vessel count, and TEU/CEU capacity totals by PORT_ID, PORT_NAME, and MONTH_YEAR.
    """
    # Ensure TIMESTAMP_UTC is datetime
    df_enriched["TIMESTAMP_UTC"] = pd.to_datetime(df_enriched["TIMESTAMP_UTC"], errors='coerce', dayfirst=True)
    df_enriched["MONTH_YEAR"] = df_enriched["TIMESTAMP_UTC"].dt.strftime('%Y-%m')

    agg = df_enriched.groupby(['PORT_ID', 'PORT_NAME', 'MONTH_YEAR']).agg(
        total_arrivals=('SHIP_ID', 'count'),
        vessel_count=('IMO', 'nunique'),
        teu_capacity_total=('TEU/CAPACITY', lambda x: pd.to_numeric(x, errors='coerce').sum()),
        ceu_capacity_total=('CEU/CAPACITY', lambda x: pd.to_numeric(x, errors='coerce').sum())
    ).reset_index()

    agg['teu_capacity_total'] = agg['teu_capacity_total'].astype('Int64')
    agg['ceu_capacity_total'] = agg['ceu_capacity_total'].astype('Int64')

    if output_filename:
        agg.to_csv(output_filename, index=False)
        print(f"Aggregation saved to {output_filename}")

    return agg

# %%
# ================================================
# Section 10: Main Function
# ================================================
def main():
    print("MarineTraffic Port Calls + Fleet Management Tool")
    print("Aggregation from existing enriched file.\n")

    try:
        # Step 1: User input for Port Calls (any region)
        region, from_date, to_date, market_list, movetype = get_user_portcall_input()
        region = region.strip().upper()  # Normalize region value

        # Step 2: Fetch Port Call Data (batched if needed)
        print("\n=== Step 2: Fetch Port Call Data ===")
        data = fetch_portcall_data(region, from_date, to_date, market_list, movetype)
        if not data:
            print("No port call data returned.")
            return

        df_portcalls = normalize_portcall_data(data)
        print(f"Fetched {len(df_portcalls)} port call records.")
        portcalls_csv = save_df_to_csv(df_portcalls)
        print(f"✅ Port calls saved to {portcalls_csv}")

        # Step 3: Extract unique IMOs for adding to fleet
        imo_list = df_portcalls['IMO'].dropna().astype(str).unique().tolist()

        # Step 4: Clear Fleet (TEMPORARILY DISABLED)
        print("\n=== Step 4: Clear Fleet ===")
        cleared = clear_fleet(CLEARFLEET_API_KEY, FLEET_ID)
        if not cleared:
            print("Fleet clearing failed. Aborting.")
            return

        # Step 5: Add vessels to Fleet (TEMPORARILY DISABLED)
        add_vessels_to_fleet(SETFLEET_API_KEY, FLEET_ID, imo_list)

        # Step 6: Fetch Fleet Port Calls (batched if needed) and enrich
        fleet_filename = save_fleet_portcalls(FLEET_PORTCALL_API_KEY, from_date, to_date, region=region)
        if not fleet_filename:
            print("No fleet data to enrich port calls.")
            return
        df_fleet_portcalls = pd.read_csv(fleet_filename)

        # Enrich with last non-region departure and next non-region arrival
        df_enriched = enrich_portcalls_with_last_and_next(df_portcalls, df_fleet_portcalls, region)
        print(f"Enriched {len(df_enriched)} port call records.")

        # Step 7: Fetch Particulars using GraphQL and merge
        print("\n=== Step 7: Fetching Vessel Particulars for vessels via GraphQL API ===")
        imo_list = df_enriched['IMO'].dropna().astype(str).unique().tolist()
        df_teu = fetch_teu_by_imo_list(imo_list)

        df_enriched['IMO'] = df_enriched['IMO'].astype(str)
        df_teu['IMO'] = df_teu['IMO'].astype(str)
        df_enriched = df_enriched.merge(df_teu, on="IMO", how="left")

        cols = df_enriched.columns.tolist()
        if "TEU/CAPACITY" in cols and "SHIPNAME" in cols:
            # Remove both if present, then re-insert in order
            cols.remove("TEU/CAPACITY")
            if "CEU/CAPACITY" in cols:
                cols.remove("CEU/CAPACITY")
            idx = cols.index("SHIPNAME") + 1
            cols.insert(idx, "TEU/CAPACITY")
            cols.insert(idx + 1, "CEU/CAPACITY")
            df_enriched = df_enriched[cols]

        # Arrange columns in desired order
        desired_cols = [
            "IMO", "SHIP_ID", "SHIPNAME", "TEU/CAPACITY", "CEU/CAPACITY",
            "LAST_PORT_ID", "LAST_PORT", "LAST_PORT_COUNTRY_CODE", "LAST_PORT_TIMESTAMP",
            "PORT_ID", "PORT_NAME", "LOAD_STATUS", "TIMESTAMP_UTC",
            "NEXT_PORT_ID", "NEXT_PORT", "NEXT_PORT_COUNTRY", "NEXT_PORT_TIMESTAMP"
        ]
        final_cols = [col for col in desired_cols if col in df_enriched.columns]
        df_enriched = df_enriched[final_cols]

        # Format all timestamp columns before saving
        for col in ["TIMESTAMP_UTC", "LAST_PORT_TIMESTAMP", "NEXT_PORT_TIMESTAMP"]:
            if col in df_enriched.columns:
                df_enriched[col] = pd.to_datetime(df_enriched[col], errors='coerce').dt.strftime('%d/%m/%Y %H:%M:%S')

        # Now save to CSV
        enriched_filename = f"{region.lower()}_portcalls_enriched_{datetime.utcnow().strftime('%Y%m%d_%H%M')}.csv"
        df_enriched.to_csv(enriched_filename, index=False)
        print(f"✅ Enriched port calls saved to {enriched_filename}")   

        agg_arrivals = aggregate_total_port_arrivals(df_enriched, output_filename=f'{region.lower()}_port_aggregation.csv')
        print(f"✅ Aggregation complete. Output: {region.lower()}_port_aggregation.csv")

    except KeyboardInterrupt:
        print("\nUser exited program.")
    except Exception as e:
        print(f"❌ Unexpected error: {e}")

if __name__ == "__main__":
    main()
# Out:
# MarineTraffic Port Calls + Fleet Management Tool
# Aggregation from existing enriched file.
#
#
# Available Market Types:
# 1. CONTAINER SHIPS
# 2. DRY BREAKBULK
# 3. DRY BULK
# 4. LNG CARRIERS
# 5. LPG CARRIERS
# 6. WET BULK
# 7. PASSENGER SHIPS
# 8. OFFSHORE/RIGS
# 9. RO/RO
# 10. SUPPORTING VESSELS
# 11. PLEASURE CRAFT
# 12. FISHING
# 13. OTHER MARKETS
#
# === Step 2: Fetch Port Call Data ===
# Fetching port calls from 2024-01-01 00:00:00 to 2024-07-08 00:00:00...
# Fetching port calls from 2024-07-08 00:00:01 to 2025-01-13 00:00:01...
# Fetching port calls from 2025-01-13 00:00:02 to 2025-07-21 00:00:02...
# Fetching port calls from 2025-07-21 00:00:03 to 2025-08-10 23:59:00...
# Fetched 33761 port call records.
# ✅ Port calls saved to portcalls_20250811_1131.csv
#
# [Batch 2] ✅ IMO 9395135 added.
# [Batch 2] ✅ IMO 9861897 added.
# [Batch 2] ✅ IMO 9222297 added.
# [Batch 2] ✅ IMO 9348699 added.
# [Batch 2] ✅ IMO 9704984 added.
# [Batch 2] ✅ IMO 9704647 added.
# [Batch 2] ✅ IMO 9450416 added.
# [Batch 2] ✅ IMO 9331000 added.
# [Batch 2] ✅ IMO 9588081 added.
# [Batch 2] ✅ IMO 9814612 added.
# [Batch 2] ✅ IMO 9215191 added.
# [Batch 2] ✅ IMO 9247742 added.
# [Batch 2] ✅ IMO 9351127 added.
# [Batch 2] ✅ IMO 9850850 added.
# [Batch 2] ✅ IMO 9416989 added.
# [Batch 2] ✅ IMO 9357119 added.
# [Batch 2] ✅ IMO 9347425 added.
# [Batch 2] ✅ IMO 9365879 added.
# [Batch 2] ✅ IMO 9371426 added.
# [Batch 2] ✅ IMO 9741425 added.
# [Batch 2] ✅ IMO 9437127 added.
# [Batch 2] ✅ IMO 9349502 added.
# [Batch 2] ✅ IMO 9697428 added.
# [Batch 2] ✅ IMO 9241475 added.
# [Batch 2] ✅ IMO 9401166 added.
# [Batch 2] ✅ IMO 9304978 added.
# [Batch 2] ✅ IMO 9630365 added.
# [Batch 2] ✅ IMO 9674517 added.
# [Batch 2] ✅ IMO 9619476 added.
# [Batch 2] ✅ IMO 9969625 added.
# [Batch 2] ✅ IMO 9317975 added.
# [Batch 2] ✅ IMO 9225275 added.
# [Batch 2] ✅ IMO 9951537 added.
# [Batch 2] ✅ IMO 9359038 added.
# [Batch 2] ✅ IMO 9295373 added.
# [Batch 2] ✅ IMO 9768007 added.
# [Batch 2] ✅ IMO 9290098 added.
# [Batch 2] ✅ IMO 9760598 added.
# [Batch 2] ✅ IMO 9415727 added.
# [Batch 2] ✅ IMO 9302889 added.
# [Batch 2] ✅ IMO 9630377 added.
# [Batch 2] ✅ IMO 9401661 added.
# [Batch 2] ✅ IMO 9664275 added.
# [Batch 2] ✅ IMO 9374442 added.
# [Batch 2] ✅ IMO 9350018 added.
# [Batch 2] ✅ IMO 9293777 added.
# [Batch 2] ✅ IMO 9185293 added.
# [Batch 2] ✅ IMO 9703069 added.
# [Batch 2] ✅ IMO 9535163 added.
# [Batch 2] ✅ IMO 9334143 added.
# [Batch 2] ✅ IMO 9733820 added.
# [Batch 2] ✅ IMO 9967495 added.
# [Batch 2] ✅ IMO 9221815 added.
# [Batch 2] ✅ IMO 9333034 added.
# [Batch 2] ✅ IMO 9963217 added.
# [Batch 2] ✅ IMO 9299800 added.
# [Batch 2] ✅ IMO 9340764 added.
# [Batch 2] ✅ IMO 9850824 added.
# [Batch 2] ✅ IMO 9404869 added.
# [Batch 2] ✅ IMO 9215919 added.
# [Batch 2] ✅ IMO 9745500 added.
# [Batch 2] ✅ IMO 9210086 added.
# [Batch 2] ✅ IMO 9448774 added.
# [Batch 2] ✅ IMO 9359014 added.
# [Batch 2] ✅ IMO 9627978 added.
# [Batch 2] ✅ IMO 9941128 added.
# [Batch 2] ✅ IMO 9419656 added.
# [Batch 2] ✅ IMO 9724049 added.
# [Batch 2] ✅ IMO 9305506 added.
# [Batch 2] ✅ IMO 9237151 added.
# [Batch 2] ✅ IMO 9110547 added.
# [Batch 2] ✅ IMO 9293820 added.
# [Batch 2] ✅ IMO 9937347 added.
# [Batch 2] ✅ IMO 9472141 added.
# [Batch 2] ✅ IMO 9246700 added.
# [Batch 2] ✅ IMO 9619452 added.
# [Batch 2] ✅ IMO 9786750 added.
# [Batch 2] ✅ IMO 9861885 added.
# [Batch 2] ✅ IMO 9294381 added.
# [Batch 2] ✅ IMO 9525871 added.
# [Batch 2] ✅ IMO 9728916 added.
# [Batch 2] ✅ IMO 9376907 added.
# [Batch 2] ✅ IMO 9312987 added.
# [Batch 2] ✅ IMO 9869693 added.
# [Batch 2] ✅ IMO 9516428 added.
# [Batch 2] ✅ IMO 9664897 added.
# [Batch 2] ✅ IMO 9198109 added.
# [Batch 2] ✅ IMO 9466960 added.
# [Batch 2] ✅ IMO 9440801 added.
# [Batch 2] ✅ IMO 9311701 added.
# [Batch 2] ✅ IMO 9392925 added.
# [Batch 2] ✅ IMO 9267649 added.
# [Batch 2] ✅ IMO 9970947 added.
# [Batch 2] ✅ IMO 9535137 added.
# [Batch 2] ✅ IMO 9407160 added.
# [Batch 2] ✅ IMO 9431630 added.
# [Batch 2] ✅ IMO 9516416 added.
# [Batch 2] ✅ IMO 9241190 added.
# [Batch 2] ✅ IMO 9810915 added.
# [Batch 2] ✅ IMO 9461893 added.
# [Batch 2] ✅ IMO 9447873 added.
# [Batch 2] ✅ IMO 9462718 added.
# [Batch 2] ✅ IMO 9680853 added.
# [Batch 2] ✅ IMO 9324849 added.
# [Batch 2] ✅ IMO 9406934 added.
# [Batch 2] ✅ IMO 9241310 added.
# [Batch 2] ✅ IMO 9262704 added.
# [Batch 2] ✅ IMO 9225641 added.
# [Batch 2] ✅ IMO 9297840 added.
# [Batch 2] ✅ IMO 9967988 added.
# [Batch 2] ✅ IMO 9756092 added.
# [Batch 2] ✅ IMO 9289958 added.
# [Batch 2] ✅ IMO 9453559 added.
# [Batch 2] ✅ IMO 9446104 added.
# [Batch 2] ✅ IMO 9704972 added.
# [Batch 2] ✅ IMO 9337925 added.
# [Batch 2] ✅ IMO 9435038 added.
# [Batch 2] ✅ IMO 9326744 added.
# [Batch 2] ✅ IMO 9867839 added.
# [Batch 2] ✅ IMO 9725160 added.
# [Batch 2] ✅ IMO 9120841 added.
# [Batch 2] ✅ IMO 9441001 added.
# [Batch 2] ✅ IMO 9429194 added.
# [Batch 2] ✅ IMO 9374454 added.
# [Batch 2] ✅ IMO 9290103 added.
# [Batch 2] ✅ IMO 9943073 added.
# [Batch 2] ✅ IMO 9337652 added.
# [Batch 2] ✅ IMO 9251690 added.
# [Batch 2] ✅ IMO 9343728 added.
# [Batch 2] ✅ IMO 9349526 added.
# [Batch 2] ✅ IMO 9362334 added.
# [Batch 2] ✅ IMO 9778131 added.
# [Batch 2] ✅ IMO 9348065 added.
# [Batch 2] ✅ IMO 9665621 added.
# [Batch 2] ✅ IMO 9252541 added.
# [Batch 2] ✅ IMO 9299549 added.
# [Batch 2] ✅ IMO 9308390 added.
# [Batch 2] ✅ IMO 9218686 added.
# [Batch 2] ✅ IMO 9792618 added.
# [Batch 2] ✅ IMO 9143568 added.
# [Batch 2] ✅ IMO 9359026 added.
# [Batch 2] ✅ IMO 9628180 added.
# [Batch 2] ✅ IMO 9287924 added.
# [Batch 2] ✅ IMO 9300453 added.
# [Batch 2] ✅ IMO 9439747 added.
# [Batch 2] ✅ IMO 9388340 added.
# [Batch 2] ✅ IMO 9395927 added.
# [Batch 2] ✅ IMO 9477359 added.
# [Batch 2] ✅ IMO 9426805 added.
# [Batch 2] ✅ IMO 9215323 added.
# [Batch 2] ✅ IMO 9192442 added.
# [Batch 2] ✅ IMO 9805453 added.
# [Batch 2] ✅ IMO 9757230 added.
# [Batch 2] ✅ IMO 9719056 added.
# [Batch 2] ✅ IMO 9480186 added.
# [Batch 2] ✅ IMO 9302097 added.
# [Batch 2] ✅ IMO 9293818 added.
# [Batch 2] ✅ IMO 9757864 added.
# [Batch 2] ✅ IMO 9365829 added.
# [Batch 2] ✅ IMO 9309459 added.
# [Batch 2] ✅ IMO 9734159 added.
# [Batch 2] ✅ IMO 9932490 added.
# [Batch 2] ✅ IMO 9102746 added.
# [Batch 2] ✅ IMO 9399777 added.
# [Batch 2] ✅ IMO 9718935 added.
# [Batch 2] ✅ IMO 9630420 added.
# [Batch 2] ✅ IMO 9780861 added.
# [Batch 2] ✅ IMO 9222986 added.
# [Batch 2] ✅ IMO 9303780 added.
# [Batch 2] ✅ IMO 9314947 added.
# [Batch 2] ✅ IMO 9437050 added.
# [Batch 2] ✅ IMO 9395159 added.
# [Batch 2] ✅ IMO 9739678 added.
# [Batch 2] ✅ IMO 9311787 added.
# [Batch 2] ✅ IMO 9251999 added.
# [Batch 2] ✅ IMO 9322463 added.
# [Batch 2] ✅ IMO 9756107 added.
# [Batch 2] ✅ IMO 9294379 added.
# [Batch 2] ✅ IMO 9402627 added.
# [Batch 2] ✅ IMO 9290282 added.
# [Batch 2] ✅ IMO 9246712 added.
# [Batch 2] ✅ IMO 9486087 added.
# [Batch 2] ✅ IMO 9359002 added.
# [Batch 2] ✅ IMO 9618276 added.
# [Batch 2] ✅ IMO 9785744 added.
# [Batch 2] ✅ IMO 9331012 added.
# [Batch 2] ✅ IMO 9623673 added.
# [Batch 2] ✅ IMO 9345415 added.
# [Batch 2] ✅ IMO 9793909 added.
# [Batch 2] ✅ IMO 9406752 added.
# [Batch 2] ✅ IMO 9741437 added.
# [Batch 2] ✅ IMO 9315214 added.
# [Batch 2] ✅ IMO 9302073 added.
# [Batch 2] ✅ IMO 9459101 added.
# [Batch 2] ✅ IMO 9927251 added.
# [Batch 2] ✅ IMO 9226425 added.
# [Batch 2] ✅ IMO 9282261 added.
# [Batch 2] ✅ IMO 9737503 added.
# [Batch 2] ✅ IMO 9247546 added.
# [Batch 2] ✅ IMO 9312755 added.
# [Batch 2] ✅ IMO 9318046 added.
# [Batch 2] ✅ IMO 9622631 added.
# [Batch 2] ✅ IMO 9928217 added.
# [Batch 2] ✅ IMO 9492713 added.
# [Batch 2] ✅ IMO 9757888 added.
# [Batch 2] ✅ IMO 9472165 added.
# [Batch 2] ✅ IMO 9251638 added.
# [Batch 2] ✅ IMO 9298698 added.
# [Batch 2] ✅ IMO 9289087 added.
# [Batch 2] ✅ IMO 9785768 added.
# [Batch 2] ✅ IMO 9299642 added.
# [Batch 2] ✅ IMO 9802504 added.
# [Batch 2] ✅ IMO 9306172 added.
# [Batch 2] ✅ IMO 9295957 added.
# [Batch 2] ✅ IMO 9123154 added.
# [Batch 2] ✅ IMO 9235579 added.
# [Batch 2] ✅ IMO 9627928 added.
# [Batch 2] ✅ IMO 9535204 added.
# [Batch 2] ✅ IMO 9705079 added.
# [Batch 2] ✅ IMO 9725134 added.
# [Batch 2] ✅ IMO 9349825 added.
# [Batch 2] ✅ IMO 9462720 added.
# [Batch 2] ✅ IMO 9398383 added.
# [Batch 2] ✅ IMO 9286231 added.
# [Batch 2] ✅ IMO 9285653 added.
# [Batch 2] ✅ IMO 9720196 added.
# [Batch 2] ✅ IMO 9930947 added.
# [Batch 2] ✅ IMO 9645865 added.
# [Batch 2] ✅ IMO 9423035 added.
# [Batch 2] ✅ IMO 9321249 added.
# [Batch 2] ✅ IMO 9732606 added.
# [Batch 2] ✅ IMO 9349564 added.
# [Batch 2] ✅ IMO 9857432 added.
# [Batch 2] ✅ IMO 9231808 added.
# [Batch 2] ✅ IMO 9930387 added.
# [Batch 2] ✅ IMO 9389306 added.
# [Batch 2] ✅ IMO 9605243 added.
# [Batch 2] ✅ IMO 9251614 added.
# [Batch 2] ✅ IMO 9447859 added.
# [Batch 2] ✅ IMO 9778399 added.
# [Batch 2] ✅ IMO 9951525 added.
# [Batch 2] ✅ IMO 9697416 added.
# [Batch 2] ✅ IMO 9850575 added.
# [Batch 2] ✅ IMO 9704623 added.
# [Batch 2] ✅ IMO 9401283 added.
# [Batch 2] ✅ IMO 9320257 added.
# [Batch 2] ✅ IMO 9225615 added.
# [Batch 2] ✅ IMO 9299537 added.
# [Batch 2] ✅ IMO 9143544 added.
# [Batch 2] ✅ IMO 9337626 added.
# [Batch 2] ✅ IMO 9464699 added.
# [Batch 2] ✅ IMO 9387463 added.
# [Batch 2] ✅ IMO 9449833 added.
# [Batch 2] ✅ IMO 9273686 added.
# [Batch 2] ✅ IMO 9463281 added.
# [Batch 2] ✅ IMO 9525924 added.
# [Batch 2] ✅ IMO 9516753 added.
# [Batch 2] ✅ IMO 9401142 added.
# [Batch 2] ✅ IMO 9945485 added.
# [Batch 2] ✅ IMO 9300403 added.
# [Batch 2] ✅ IMO 9525936 added.
# [Batch 2] ✅ IMO 9878503 added.
# [Batch 2] ✅ IMO 9336048 added.
# [Batch 2] ✅ IMO 9882487 added.
# [Batch 2] ✅ IMO 9475612 added.
# [Batch 2] ✅ IMO 9365855 added.
# [Batch 2] ✅ IMO 9300790 added.
# [Batch 2] ✅ IMO 9356701 added.
# [Batch 2] ✅ IMO 9254848 added.
# [Batch 2] ✅ IMO 9342516 added.
# [Batch 3] ✅ IMO 9417256 added.
# [Batch 3] ✅ IMO 9256755 added.
# [Batch 3] ✅ IMO 9463023 added.
# [Batch 3] ✅ IMO 9337913 added.
# [Batch 3] ✅ IMO 9301433 added.
# [Batch 3] ✅ IMO 9850549 added.
# [Batch 3] ✅ IMO 9850874 added.
# [Batch 3] ✅ IMO 9461881 added.
# [Batch 3] ✅ IMO 9629031 added.
# [Batch 3] ✅ IMO 9348687 added.
# [Batch 3] ✅ IMO 9337482 added.
# [Batch 3] ✅ IMO 9294393 added.
# [Batch 3] ✅ IMO 9741449 added.
# [Batch 3] ✅ IMO 9785794 added.
# [Batch 3] ✅ IMO 9356713 added.
# [Batch 3] ✅ IMO 9450428 added.
# [Batch 3] ✅ IMO 9416991 added.
# [Batch 3] ✅ IMO 9700251 added.
# [Batch 3] ✅ IMO 9627980 added.
# [Batch 3] ✅ IMO 9792709 added.
# [Batch 3] ✅ IMO 9347542 added.
# [Batch 3] ✅ IMO 9367190 added.
# [Batch 3] ✅ IMO 9200691 added.
# [Batch 3] ✅ IMO 9150212 added.
# [Batch 3] ✅ IMO 9627916 added.
# [Batch 3] ✅ IMO 9315202 added.
# [Batch 3] ✅ IMO 9301990 added.
# [Batch 3] ✅ IMO 9290115 added.
# [Batch 3] ✅ IMO 9484479 added.
# [Batch 3] ✅ IMO 9300415 added.
# [Batch 3] ✅ IMO 9352004 added.
# [Batch 3] ✅ IMO 9348053 added.
# [Batch 3] ✅ IMO 9398424 added.
# [Batch 3] ✅ IMO 9398216 added.
# [Batch 3] ✅ IMO 9943097 added.
# [Batch 3] ✅ IMO 9462732 added.
# [Batch 3] ✅ IMO 9312949 added.
# [Batch 3] ✅ IMO 9289960 added.
# [Batch 3] ✅ IMO 9221827 added.
# [Batch 3] ✅ IMO 9950129 added.
# [Batch 3] ✅ IMO 9293167 added.
# [Batch 3] ✅ IMO 9418652 added.
# [Batch 3] ✅ IMO 9349497 added.
# [Batch 3] ✅ IMO 9196864 added.
# [Batch 3] ✅ IMO 9713337 added.
# [Batch 3] ✅ IMO 9312999 added.
# [Batch 3] ✅ IMO 9399753 added.
# [Batch 3] ✅ IMO 9345439 added.
# [Batch 3] ✅ IMO 9972892 added.
# [Batch 3] ✅ IMO 9741401 added.
# [Batch 3] ✅ IMO 9450624 added.
# [Batch 3] ✅ IMO 9770737 added.
# [Batch 3] ✅ IMO 9262716 added.
# [Batch 3] ✅ IMO 9229300 added.
# [Batch 3] ✅ IMO 9950131 added.
# [Batch 3] ✅ IMO 9430399 added.
# [Batch 3] ✅ IMO 9283198 added.
# [Batch 3] ✅ IMO 9197545 added.
# [Batch 3] ✅ IMO 9401051 added.
# [Batch 3] ✅ IMO 9629079 added.
# [Batch 3] ✅ IMO 9372482 added.
# [Batch 3] ✅ IMO 9349813 added.
# [Batch 3] ✅ IMO 9290567 added.
# [Batch 3] ✅ IMO 9224520 added.
# [Batch 3] ✅ IMO 9440837 added.
# [Batch 3] ✅ IMO 9337937 added.
# [Batch 3] ✅ IMO 7226689 added.
# [Batch 3] ✅ IMO 9667186 added.
# [Batch 3] ✅ IMO 9468310 added.
# [Batch 3] ✅ IMO 9417244 added.
# [Batch 3] ✅ IMO 9316361 added.
# [Batch 3] ✅ IMO 9359040 added.
# [Batch 3] ✅ IMO 9342504 added.
# [Batch 3] ✅ IMO 9214214 added.
# [Batch 3] ✅ IMO 9189342 added.
# [Batch 3] ✅ IMO 9408853 added.
# [Batch 3] ✅ IMO 9850525 added.
# [Batch 3] ✅ IMO 9435246 added.
# [Batch 3] ✅ IMO 9312779 added.
# [Batch 3] ✅ IMO 9627899 added.
# [Batch 3] ✅ IMO 9301809 added.
# [Batch 3] ✅ IMO 9676723 added.
# [Batch 3] ✅ IMO 9629469 added.
# [Batch 3] ✅ IMO 9290476 added.
# [Batch 3] ✅ IMO 9260445 added.
# [Batch 3] ✅ IMO 9595450 added.
# [Batch 3] ✅ IMO 9699115 added.
# [Batch 3] ✅ IMO 9765586 added.
# [Batch 3] ✅ IMO 9611058 added.
# [Batch 3] ✅ IMO 9969912 added.
# [Batch 3] ✅ IMO 9792694 added.
# [Batch 3] ✅ IMO 9475648 added.
# [Batch 3] ✅ IMO 9732591 added.
# [Batch 3] ✅ IMO 9930961 added.
# [Batch 3] ✅ IMO 9400069 added.
# [Batch 3] ✅ IMO 9299783 added.
# [Batch 3] ✅ IMO 9516454 added.
# [Batch 3] ✅ IMO 9604081 added.
# [Batch 3] ✅ IMO 9850862 added.
# [Batch 3] ✅ IMO 9337614 added.
# [Batch 3] ✅ IMO 9708459 added.
# [Batch 3] ✅ IMO 9484560 added.
# [Batch 3] ✅ IMO 9525900 added.
# [Batch 3] ✅ IMO 9481532 added.
# [Batch 3] ✅ IMO 9310238 added.
# [Batch 3] ✅ IMO 9351141 added.
# [Batch 3] ✅ IMO 9300805 added.
# [Batch 3] ✅ IMO 9351139 added.
# [Batch 3] ✅ IMO 9227314 added.
# [Batch 3] ✅ IMO 9290531 added.
# [Batch 3] ✅ IMO 9403619 added.
# [Batch 3] ✅ IMO 9359052 added.
# [Batch 3] ✅ IMO 9516430 added.
# [Batch 3] ✅ IMO 9190731 added.
# [Batch 3] ✅ IMO 9860908 added.
# [Batch 3] ✅ IMO 9360752 added.
# [Batch 3] ✅ IMO 9333010 added.
# [Batch 3] ✅ IMO 9472153 added.
# [Batch 3] ✅ IMO 9969390 added.
# [Batch 3] ✅ IMO 9338084 added.
# [Batch 3] ✅ IMO 9302138 added.
# [Batch 3] ✅ IMO 9294537 added.
# [Batch 3] ✅ IMO 9229324 added.
# [Batch 3] ✅ IMO 9850563 added.
# [Batch 3] ✅ IMO 9306196 added.
# [Batch 3] ✅ IMO 9690092 added.
# [Batch 3] ✅ IMO 9222302 added.
# [Batch 3] ✅ IMO 9355563 added.
# [Batch 3] ✅ IMO 9294989 added.
# [Batch 3] ✅ IMO 9300427 added.
# [Batch 3] ✅ IMO 9253026 added.
# [Batch 3] ✅ IMO 9555113 added.
# [Batch 3] ✅ IMO 9400083 added.
# [Batch 3] ✅ IMO 9386495 added.
# [Batch 3] ✅ IMO 9645906 added.
# [Batch 3] ✅ IMO 9409027 added.
# [Batch 3] ✅ IMO 9742168 added.
# [Batch 3] ✅ IMO 9702106 added.
# [Batch 3] ✅ IMO 9789996 added.
# [Batch 3] ✅ IMO 9337444 added.
# [Batch 3] ✅ IMO 9751092 added.
# [Batch 3] ✅ IMO 9406611 added.
# [Batch 3] ✅ IMO 9252553 added.
# [Batch 3] ✅ IMO 9699189 added.
# [Batch 3] ✅ IMO 9295268 added.
# [Batch 3] ✅ IMO 9679907 added.
# [Batch 3] ✅ IMO 9193305 added.
# [Batch 3] ✅ IMO 9226920 added.
# [Batch 3] ✅ IMO 9261451 added.
# [Batch 3] ✅ IMO 9215880 added.
# [Batch 3] ✅ IMO 9468308 added.
# [Batch 3] ✅ IMO 9453365 added.
# [Batch 3] ✅ IMO 9938327 added.
# [Batch 3] ✅ IMO 9632040 added.
# [Batch 3] ✅ IMO 9320233 added.
# [Batch 3] ✅ IMO 9110377 added.
# [Batch 3] ✅ IMO 9475624 added.
# [Batch 3] ✅ IMO 9605152 added.
# [Batch 3] ✅ IMO 9181663 added.
# [Batch 3] ✅ IMO 9343089 added.
# [Batch 3] ✅ IMO 9792682 added.
# [Batch 3] ✅ IMO 9628001 added.
# [Batch 3] ✅ IMO 9310240 added.
# [Batch 3] ✅ IMO 9461867 added.
# [Batch 3] ✅ IMO 9424900 added.
# [Batch 3] ✅ IMO 9674529 added.
# [Batch 3] ✅ IMO 9434462 added.
# [Batch 3] ✅ IMO 9516404 added.
# [Batch 3] ✅ IMO 9525883 added.
# [Batch 3] ✅ IMO 9362401 added.
# [Batch 3] ✅ IMO 9784776 added.
# [Batch 3] ✅ IMO 9603609 added.
# [Batch 3] ✅ IMO 9484948 added.
# [Batch 3] ✅ IMO 9369734 added.
# [Batch 3] ✅ IMO 9931109 added.
# [Batch 3] ✅ IMO 9444261 added.
# [Batch 3] ✅ IMO 9337664 added.
# [Batch 3] ✅ IMO 9334674 added.
# [Batch 3] ✅ IMO 9467407 added.
# [Batch 3] ✅ IMO 9304411 added.
# [Batch 3] ✅ IMO 9484572 added.
# [Batch 3] ✅ IMO 9245770 added.
# [Batch 3] ✅ IMO 9327798 added.
# [Batch 3] ✅ IMO 9211494 added.
# [Batch 3] ✅ IMO 9224049 added.
# [Batch 3] ✅ IMO 9622590 added.
# [Batch 3] ✅ IMO 9839911 added.
# [Batch 3] ✅ IMO 9743502 added.
# [Batch 3] ✅ IMO 9850898 added.
# [Batch 3] ✅ IMO 9243186 added.
# [Batch 3] ✅ IMO 9190779 added.
# [Batch 3] ✅ IMO 9531909 added.
# [Batch 3] ✅ IMO 9411367 added.
# [Batch 3] ✅ IMO 9785809 added.
# [Batch 3] ✅ IMO 9780897 added.
# [Batch 3] ✅ IMO 9629081 added.
# [Batch 3] ✅ IMO 9417268 added.
# [Batch 6] ✅ IMO 9362449 added.
# [Batch 6] ✅ IMO 9315226 added.
# [Batch 6] ✅ IMO 9229831 added.
# [Batch 6] ✅ IMO 9954151 added.
# [Batch 6] ✅ IMO 9484924 added.
# [Batch 6] ✅ IMO 9322499 added.
# [Batch 6] ✅ IMO 9231494 added.
# [Batch 6] ✅ IMO 9455296 added.
# [Batch 6] ✅ IMO 9613018 added.
# [Batch 6] ✅ IMO 9450399 added.
# [Batch 6] ✅ IMO 9243394 added.
# [Batch 6] ✅ IMO 9406180 added.
# [Batch 6] ✅ IMO 9634684 added.
# [Batch 6] ✅ IMO 9984247 added.
# [Batch 6] ✅ IMO 9374571 added.
# [Batch 6] ✅ IMO 9480174 added.
# [Batch 6] ✅ IMO 9571313 added.
# [Batch 6] ✅ IMO 9256315 added.
# [Batch 6] ✅ IMO 9484998 added.
# [Batch 6] ✅ IMO 9722704 added.
# [Batch 6] ✅ IMO 9463085 added.
# [Batch 6] ✅ IMO 9168879 added.
# [Batch 6] ✅ IMO 9260914 added.
# [Batch 6] ✅ IMO 9410727 added.
# [Batch 6] ✅ IMO 9964417 added.
# [Batch 6] ✅ IMO 9944807 added.
# [Batch 6] ✅ IMO 9162227 added.
# [Batch 6] ✅ IMO 9404730 added.
# [Batch 6] ✅ IMO 9595448 added.
# [Batch 6] ✅ IMO 9969065 added.
# [Batch 6] ✅ IMO 9292436 added.
# [Batch 6] ✅ IMO 9825403 added.
# [Batch 6] ✅ IMO 9935088 added.
# [Batch 6] ✅ IMO 9450349 added.
# [Batch 6] ✅ IMO 9398242 added.
# [Batch 6] ✅ IMO 9353292 added.
# [Batch 6] ✅ IMO 9757187 added.
# [Batch 6] ✅ IMO 9983695 added.
# [Batch 6] ✅ IMO 9949728 added.
# [Batch 6] ✅ IMO 9679892 added.
# [Batch 6] ✅ IMO 9286786 added.
# [Batch 6] ✅ IMO 9198288 added.
# [Batch 6] ✅ IMO 9337456 added.
# [Batch 6] ✅ IMO 9964235 added.
# [Batch 6] ✅ IMO 9345403 added.
# [Batch 6] ✅ IMO 9641223 added.
# [Batch 6] ✅ IMO 9720524 added.
# [Batch 6] ✅ IMO 9380271 added.
# [Batch 6] ✅ IMO 9560352 added.
# [Batch 6] ✅ IMO 9456953 added.
# [Batch 6] ✅ IMO 9979278 added.
# [Batch 6] ✅ IMO 9308194 added.
# [Batch 6] ✅ IMO 9430363 added.
# [Batch 6] ✅ IMO 9875381 added.
# [Batch 6] ✅ IMO 9354648 added.
# [Batch 6] ✅ IMO 9695145 added.
# [Batch 6] ✅ IMO 9283693 added.
# [Batch 6] ✅ IMO 9974474 added.
# [Batch 6] ✅ IMO 9964194 added.
# [Batch 6] ✅ IMO 9450430 added.
# [Batch 6] ✅ IMO 9295165 added.
# [Batch 6] ✅ IMO 9457737 added.
# [Batch 6] ✅ IMO 9463267 added.
# [Batch 6] ✅ IMO 9200706 added.
# [Batch 6] ✅ IMO 9339595 added.
# [Batch 6] ✅ IMO 9620619 added.
# [Batch 6] ✅ IMO 9438535 added.
# [Batch 6] ✅ IMO 9932921 added.
# [Batch 6] ✅ IMO 9934383 added.
# [Batch 6] ✅ IMO 9635676 added.
# [Batch 6] ✅ IMO 9278090 added.
# [Batch 6] ✅ IMO 9625542 added.
# [Batch 6] ✅ IMO 9385972 added.
# [Batch 6] ✅ IMO 9654464 added.
# [Batch 6] ✅ IMO 9685358 added.
# [Batch 6] ✅ IMO 9200677 added.
# [Batch 6] ✅ IMO 9252577 added.
# [Batch 6] ✅ IMO 9729075 added.
# [Batch 6] ✅ IMO 9302578 added.
# [Batch 6] ✅ IMO 9444730 added.
# [Batch 6] ✅ IMO 9229855 added.
# [Batch 6] ✅ IMO 9315381 added.
# [Batch 6] ✅ IMO 9936393 added.
# [Batch 6] ✅ IMO 9193288 added.
# [Batch 6] ✅ IMO 9565338 added.
# [Batch 6] ✅ IMO 9260902 added.
# [Batch 6] ✅ IMO 9703306 added.
# [Batch 6] ✅ IMO 9951721 added.
# [Batch 6] ✅ IMO 9706205 added.
# [Batch 6] ✅ IMO 9991202 added.
# [Batch 6] ✅ IMO 9198276 added.
# [Batch 6] ✅ IMO 9312808 added.
# [Batch 6] ✅ IMO 9679555 added.
# [Batch 6] ✅ IMO 9968059 added.
# [Batch 6] ✅ IMO 9231482 added.
# [Batch 6] ✅ IMO 9949778 added.
# [Batch 6] ✅ IMO 9805465 added.
# [Batch 6] ✅ IMO 9424924 added.
# [Batch 6] ✅ IMO 9307243 added.
# [Batch 6] ✅ IMO 9943114 added.
# [Batch 6] ✅ IMO 9359313 added.
# [Batch 6] ✅ IMO 9683843 added.
# [Batch 6] ✅ IMO 9727613 added.
# [Batch 6] ✅ IMO 9628178 added.
# [Batch 6] ✅ IMO 9525388 added.
# [Batch 6] ✅ IMO 9848742 added.
# [Batch 6] ✅ IMO 9481520 added.
# [Batch 6] ✅ IMO 9635688 added.
# [Batch 6] ✅ IMO 9295397 added.
# [Batch 6] ✅ IMO 9398412 added.
# [Batch 6] ✅ IMO 9278088 added.
# [Batch 6] ✅ IMO 9292175 added.
# [Batch 6] ✅ IMO 9450442 added.
# [Batch 6] ✅ IMO 9935337 added.
# [Batch 6] ✅ IMO 9613006 added.
# [Batch 6] ✅ IMO 9391787 added.
# [Batch 6] ✅ IMO 9728954 added.
# [Batch 6] ✅ IMO 9403229 added.
# [Batch 6] ✅ IMO 9331165 added.
# [Batch 6] ✅ IMO 9322487 added.
# [Batch 6] ✅ IMO 9706190 added.
# [Batch 6] ✅ IMO 9300398 added.
# [Batch 6] ✅ IMO 9200689 added.
# [Batch 6] ✅ IMO 9229348 added.
# [Batch 6] ✅ IMO 9211482 added.
# [Batch 6] ✅ IMO 9385984 added.
# [Batch 6] ✅ IMO 9294886 added.
# [Batch 6] ✅ IMO 9399789 added.
# [Batch 6] ✅ IMO 9484481 added.
# [Batch 6] ✅ IMO 9936422 added.
# [Batch 6] ✅ IMO 9525314 added.
# [Batch 6] ✅ IMO 9706310 added.
# [Batch 6] ✅ IMO 9353254 added.
# [Batch 6] ✅ IMO 9949766 added.
# [Batch 6] ✅ IMO 9687538 added.
# [Batch 6] ✅ IMO 9974539 added.
# [Batch 6] ✅ IMO 9491501 added.
# [Batch 6] ✅ IMO 9969077 added.
# [Batch 6] ✅ IMO 9337688 added.
# [Batch 6] ✅ IMO 9934369 added.
# [Batch 6] ✅ IMO 9386005 added.
# [Batch 6] ✅ IMO 9778090 added.
# [Batch 6] ✅ IMO 9465253 added.
# [Batch 6] ✅ IMO 9313931 added.
# [Batch 6] ✅ IMO 8902541 added.
# [Batch 6] ✅ IMO 9868182 added.
# [Batch 6] ✅ IMO 9727625 added.
# [Batch 6] ✅ IMO 9937543 added.
# [Batch 6] ✅ IMO 9302633 added.
# [Batch 6] ✅ IMO 9857157 added.
# [Batch 6] ✅ IMO 9780847 added.
# [Batch 6] ✅ IMO 9450387 added.
# [Batch 6] ✅ IMO 9930935 added.
# [Batch 6] ✅ IMO 9683867 added.
# [Batch 6] ✅ IMO 9465306 added.
# [Batch 6] ✅ IMO 7617905 added.
# [Batch 6] ✅ IMO 9475258 added.
# [Batch 6] ✅ IMO 9456965 added.
# [Batch 6] ✅ IMO 9224051 added.
# [Batch 6] ✅ IMO 9465241 added.
# [Batch 6] ✅ IMO 9983683 added.
# [Batch 6] ✅ IMO 9604134 added.
# [Batch 6] ✅ IMO 9503732 added.
# [Batch 6] ✅ IMO 9706748 added.
# [Batch 6] ✅ IMO 9267156 added.
# [Batch 6] ✅ IMO 9333826 added.
# [Batch 6] ✅ IMO 9952684 added.
# [Batch 6] ✅ IMO 9450571 added.
# [Batch 6] ✅ IMO 9934371 added.
# [Batch 6] ✅ IMO 9967316 added.
# [Batch 6] ✅ IMO 9399014 added.
# [Batch 6] ✅ IMO 9440150 added.
# [Batch 6] ✅ IMO 9492696 added.
# [Batch 6] ✅ IMO 9987287 added.
# [Batch 6] ✅ IMO 9698628 added.
# [Batch 6] ✅ IMO 9247560 added.
# [Batch 6] ✅ IMO 9463279 added.
# [Batch 6] ✅ IMO 9694579 added.
# [Batch 6] ✅ IMO 9502946 added.
# [Batch 6] ✅ IMO 9972127 added.
# [Batch 6] ✅ IMO 9307229 added.
# [Batch 6] ✅ IMO 9946867 added.
# [Batch 6] ✅ IMO 9554078 added.
# [Batch 6] ✅ IMO 9947146 added.
# [Batch 6] ✅ IMO 9955789 added.
# [Batch 6] ✅ IMO 9627904 added.
# [Batch 6] ✅ IMO 9972983 added.
# [Batch 6] ✅ IMO 9842097 added.
# [Batch 6] ✅ IMO 9685334 added.
# [Batch 6] ✅ IMO 9461427 added.
# [Batch 6] ✅ IMO 9868431 added.
# [Batch 6] ✅ IMO 9292149 added.
# [Batch 6] ✅ IMO 9962548 added.
# [Batch 6] ✅ IMO 9719862 added.
# [Batch 6] ✅ IMO 9430387 added.
# [Batch 6] ✅ IMO 9962615 added.
# [Batch 6] ✅ IMO 9404857 added.
# [Batch 6] ✅ IMO 9964510 added.
# [Batch 6] ✅ IMO 9508299 added.
# [Batch 6] ✅ IMO 9539688 added.
# [Batch 6] ✅ IMO 9353280 added.
# [Batch 6] ✅ IMO 9399222 added.
# [Batch 6] ✅ IMO 9359727 added.
# [Batch 6] ✅ IMO 9554080 added.
# [Batch 6] ✅ IMO 9951575 added.
# [Batch 6] ✅ IMO 9302164 added.
# [Batch 6] ✅ IMO 9959577 added.
# [Batch 6] ✅ IMO 9699206 added.
# [Batch 6] ✅ IMO 9459424 added.
# [Batch 6] ✅ IMO 9839284 added.
# [Batch 6] ✅ IMO 9437048 added.
# [Batch 6] ✅ IMO 8815308 added.
# [Batch 6] ✅ IMO 9595503 added.
# [Batch 6] ✅ IMO 9347956 added.
# [Batch 6] ✅ IMO 9343974 added.
# [Batch 6] ✅ IMO 9443035 added.
# [Batch 6] ✅ IMO 9687564 added.
# [Batch 6] ✅ IMO 9224300 added.
# [Batch 6] ✅ IMO 9248124 added.
# [Batch 6] ✅ IMO 9450404 added.
# [Batch 6] ✅ IMO 9462029 added.
# [Batch 6] ✅ IMO 9229312 added.
# [Batch 6] ✅ IMO 9984340 added.
# [Batch 6] ✅ IMO 9936381 added.
# [Batch 6] ✅ IMO 9975569 added.
# [Batch 6] ✅ IMO 9935129 added.
# [Batch 6] ✅ IMO 9793911 added.
# [Batch 6] ✅ IMO 9484431 added.
# [Batch 6] ✅ IMO 9932050 added.
# [Batch 6] ✅ IMO 9762338 added.
# [Batch 6] ✅ IMO 9438523 added.
# [Batch 6] ✅ IMO 9461489 added.
# [Batch 6] ✅ IMO 9867841 added.
# [Batch 6] ✅ IMO 9968530 added.
# [Batch 6] ✅ IMO 9347449 added.
# [Batch 6] ✅ IMO 9326756 added.
# [Batch 6] ✅ IMO 9293753 added.
# [Batch 6] ✅ IMO 9604108 added.
# [Batch 6] ✅ IMO 9365831 added.
# [Batch 6] ✅ IMO 9378814 added.
# [Batch 6] ✅ IMO 9934357 added.
#
# Added 1772 vessels successfully; 0 failed.
#
# === Step 4: Fleet Port Call API - All Records for US (Excl. region, Departures Only) ===
# Fetching fleet port calls for region us from 2023-11-01 00:00:00 to 2024-01-29 00:00:00...
# Fetching fleet port calls for region us from 2024-01-29 00:00:01 to 2024-04-27 00:00:01...
# Fetching fleet port calls for region us from 2024-04-27 00:00:02 to 2024-07-25 00:00:02...
# Fetching fleet port calls for region us from 2024-07-25 00:00:03 to 2024-10-22 00:00:03...
# Fetching fleet port calls for region us from 2024-10-22 00:00:04 to 2025-01-19 00:00:04...
# Fetching fleet port calls for region us from 2025-01-19 00:00:05 to 2025-04-18 00:00:05...
# Fetching fleet port calls for region us from 2025-04-18 00:00:06 to 2025-07-16 00:00:06...
# Fetching fleet port calls for region us from 2025-07-16 00:00:07 to 2025-09-10 23:59:00...
# ✅ Saved fleet port calls to us_fleet_portcalls_filtered_20250811_1134.csv
# Enriched 33761 port call records.
#
# === Step 7: Fetching Vessel Particulars for vessels via GraphQL API ===
# ✅ Enriched port calls saved to us_portcalls_enriched_20250811_1135.csv
# Aggregation saved to us_port_aggregation.csv
# ✅ Aggregation complete. Output: us_port_aggregation.csv
